# %%
# The purpose of this notebook is to evaluate a dataset of car details

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
raw = pd.read_csv('fullspecs.csv', index_col = 0, header = None, dtype=object).T
raw.head()
# Out:
# 0                                         NaN     MSRP  \
# 1  2019 Acura RDX Specs: FWD w/Technology Pkg  $40,600
# 2     2019 Acura RDX Specs: FWD w/Advance Pkg  $45,500
# 3      2019 Acura RDX Specs: FWD w/A-Spec Pkg  $43,600
# 4                   2019 Acura RDX Specs: FWD  $37,400
# 5  2019 Acura RDX Specs: AWD w/Technology Pkg  $42,600
#
# 0             Gas Mileage                             Engine  \
# 1  22 mpg City/28 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 2  22 mpg City/28 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 3  22 mpg City/27 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 4  22 mpg City/28 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 5  21 mpg City/27 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
#
# 0                         EPA Class            Style Name         Drivetrain  \
# 1  Small Sport Utility Vehicles 2WD  FWD w/Technology Pkg  Front Wheel Drive
# 2  Small Sport Utility Vehicles 2WD     FWD w/Advance Pkg  Front Wheel Drive
# 3  Small Sport Utility Vehicles 2WD      FWD w/A-Spec Pkg  Front Wheel Drive
# 4  Small Sport Utility Vehicles 2WD                   FWD  Front Wheel Drive
# 5  Small Sport Utility Vehicles 4WD  AWD w/Technology Pkg    All Wheel Drive
#
# 0 Passenger Capacity Passenger Doors     Body Style  ... Fourth Hip Room (in)  \
# 1                  5               4  Sport Utility  ...                  NaN
# 2                  5               4  Sport Utility  ...                  NaN
# 3                  5               4  Sport Utility  ...                  NaN
# 4                  5               4  Sport Utility  ...                  NaN
# 5                  5               4  Sport Utility  ...                  NaN
#
# 0 Fourth Leg Room (in) Fourth Shoulder Room (in) Fourth Head Room (in)  \
# 1                  NaN                       NaN                   NaN
# 2                  NaN                       NaN                   NaN
# 3                  NaN                       NaN                   NaN
# 4                  NaN                       NaN                   NaN
# 5                  NaN                       NaN                   NaN
#
# 0 Fifth Shoulder Room (in) Fifth Head Room (in) Fifth Hip Room (in)  \
# 1                      NaN                  NaN                 NaN
# 2                      NaN                  NaN                 NaN
# 3                      NaN                  NaN                 NaN
# 4                      NaN                  NaN                 NaN
# 5                      NaN                  NaN                 NaN
#
# 0 Fifth Leg Room (in) Corrosion Note Hybrid/Electric Components Note
# 1                 NaN            NaN                             NaN
# 2                 NaN            NaN                             NaN
# 3                 NaN            NaN                             NaN
# 4                 NaN            NaN                             NaN
# 5                 NaN            NaN                             NaN
#
# [5 rows x 235 columns]

# %%
raw.shape
# Out:
# (32316, 235)

# %%
raw.isnull().sum().sort_values()
# Out:
# 0
# NaN                                             0
# Air Bag-Frontal-Driver                          0
# Air Bag-Frontal-Passenger                       0
# Air Bag-Passenger Switch (On/Off)               0
# Air Bag-Side Body-Front                         0
# Air Bag-Side Body-Rear                          0
# Air Bag-Side Head-Front                         0
# Air Bag-Side Head-Rear                          0
# Child Safety Rear Door Locks                    0
# Daytime Running Lights                          0
# Traction Control                                0
# Night Vision                                    0
# Rollover Protection Bars                        0
# Fog Lamps                                       0
# Brakes-ABS                                      0
# Tire Pressure Monitor                           0
# Back-Up Camera                                  0
# Stability Control                               0
# Passenger Doors                                 0
# Parking Aid                                     0
# Passenger Capacity                              0
# Style Name                                      0
# MSRP                                           54
# Other Features                               1700
# Body Style                                   1716
# Drivetrain                                   1716
# Front Wheel Material                         1969
# Disc - Front (Yes or   )                     1969
# Steering Type                                1969
# Rear Wheel Material                          1969
#                                             ...
# Trans Power Take Off                        31363
# Hybrid/Electric Components Years            31441
# Hybrid/Electric Components Miles/km         31441
# Step Up Height - Side (in)                  31447
# Basic Note                                  31705
# Side Door Opening Height (in)               31749
# Side Door Opening Width (in)                31835
# Battery Range (mi)                          32037
# EPA MPG Equivalent - Combined               32048
# Cargo Volume to Seat 4 (ft³)                32088
# Fourth Head Room (in)                       32118
# Fourth Shoulder Room (in)                   32118
# Fourth Leg Room (in)                        32118
# Fourth Hip Room (in)                        32118
# Emissions Note                              32141
# Warranty Note                               32148
# EPA MPG Equivalent - Hwy                    32160
# EPA MPG Equivalent - City                   32160
# Cargo Area Length @ Floor to Seat 4 (in)    32206
# Corrosion Note                              32209
# Ninth Gear Ratio (:1)                       32230
# Hybrid/Electric Components Note             32247
# EPA Air Pollution Score                     32265
# Tenth Gear Ratio (:1)                       32270
# Aux Fuel Tank Capacity, Approx (gal)        32305
# Aux Fuel Tank Location                      32307
# Fifth Shoulder Room (in)                    32316
# Fifth Head Room (in)                        32316
# Fifth Hip Room (in)                         32316
# Fifth Leg Room (in)                         32316
# Length: 235, dtype: int64

# %% [markdown]
# ## cleaning steps
# - Rename first col to "model"
# - convert MSRP to float
# - Convert number columns to floats
# - parse year from model
# - parse Displacement Column
# - parse engine style from Engine?
# - Parse SAE Net Torque @ RPM
# - parse SAE Net Horsepower @ RPM
# - Handle - TBD - entries
# - Convert Yes/No to boolean
# - Decide how to handle missing

# %%
# rename first column to model
df = raw.rename(index=str, columns={np.nan: "model"})
df.head()
# Out:
# 0                                       model     MSRP  \
# 1  2019 Acura RDX Specs: FWD w/Technology Pkg  $40,600
# 2     2019 Acura RDX Specs: FWD w/Advance Pkg  $45,500
# 3      2019 Acura RDX Specs: FWD w/A-Spec Pkg  $43,600
# 4                   2019 Acura RDX Specs: FWD  $37,400
# 5  2019 Acura RDX Specs: AWD w/Technology Pkg  $42,600
#
# 0             Gas Mileage                             Engine  \
# 1  22 mpg City/28 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 2  22 mpg City/28 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 3  22 mpg City/27 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 4  22 mpg City/28 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
# 5  21 mpg City/27 mpg Hwy  Turbo Premium Unleaded I-4, 2.0 L
#
# 0                         EPA Class            Style Name         Drivetrain  \
# 1  Small Sport Utility Vehicles 2WD  FWD w/Technology Pkg  Front Wheel Drive
# 2  Small Sport Utility Vehicles 2WD     FWD w/Advance Pkg  Front Wheel Drive
# 3  Small Sport Utility Vehicles 2WD      FWD w/A-Spec Pkg  Front Wheel Drive
# 4  Small Sport Utility Vehicles 2WD                   FWD  Front Wheel Drive
# 5  Small Sport Utility Vehicles 4WD  AWD w/Technology Pkg    All Wheel Drive
#
# 0 Passenger Capacity Passenger Doors     Body Style  ... Fourth Hip Room (in)  \
# 1                  5               4  Sport Utility  ...                  NaN
# 2                  5               4  Sport Utility  ...                  NaN
# 3                  5               4  Sport Utility  ...                  NaN
# 4                  5               4  Sport Utility  ...                  NaN
# 5                  5               4  Sport Utility  ...                  NaN
#
# 0 Fourth Leg Room (in) Fourth Shoulder Room (in) Fourth Head Room (in)  \
# 1                  NaN                       NaN                   NaN
# 2                  NaN                       NaN                   NaN
# 3                  NaN                       NaN                   NaN
# 4                  NaN                       NaN                   NaN
# 5                  NaN                       NaN                   NaN
#
# 0 Fifth Shoulder Room (in) Fifth Head Room (in) Fifth Hip Room (in)  \
# 1                      NaN                  NaN                 NaN
# 2                      NaN                  NaN                 NaN
# 3                      NaN                  NaN                 NaN
# 4                      NaN                  NaN                 NaN
# 5                      NaN                  NaN                 NaN
#
# 0 Fifth Leg Room (in) Corrosion Note Hybrid/Electric Components Note
# 1                 NaN            NaN                             NaN
# 2                 NaN            NaN                             NaN
# 3                 NaN            NaN                             NaN
# 4                 NaN            NaN                             NaN
# 5                 NaN            NaN                             NaN
#
# [5 rows x 235 columns]

# %%
# replace '- TBD -' with np.nan
df.replace('- TBD -', np.nan, inplace = True)
df.replace('', np.nan, inplace = True)

# %%
# convert MSRP to float
df['MSRP'] = df['MSRP'].replace('[\$,]', '', regex=True).astype(float)
df['MSRP'].head()
# Out:
# 1    40600.0
# 2    45500.0
# 3    43600.0
# 4    37400.0
# 5    42600.0
# Name: MSRP, dtype: float64

# %%
# Convert number columns to floats
floatlist1 = ['Passenger Capacity', 'Passenger Doors', 'Base Curb Weight (lbs)', 'Front Hip Room (in)', 'Front Leg Room (in)', 'Second Shoulder Room (in)', 'Passenger Volume (ft³)', 'Second Head Room (in)',
             'Front Shoulder Room (in)', 'Second Hip Room (in)', 'Front Head Room (in)', 'Second Leg Room (in)', 'Wheelbase (in)', 'Min Ground Clearance (in)', 'Track Width, Front (in)', 'Width, Max w/o mirrors (in)',
             'Track Width, Rear (in)', 'Height, Overall (in)', 'Cargo Volume to Seat 1 (ft³)', 'Cargo Volume to Seat 2 (ft³)', 'Cargo Volume to Seat 3 (ft³)',
             'First Gear Ratio (:1)', 'Sixth Gear Ratio (:1)', 'Fourth Gear Ratio (:1)', 
             'Seventh Gear Ratio (:1)', 'Second Gear Ratio (:1)', 'Reverse Ratio (:1)', 'Fifth Gear Ratio (:1)', 'Eighth Gear Ratio (:1)', 'Trans Type', 'Third Gear Ratio (:1)', 'Final Drive Axle Ratio (:1)',
             'Rear Brake Rotor Diam x Thickness (in)', 'Front Brake Rotor Diam x Thickness (in)', 'Turning Diameter - Curb to Curb (ft)', 'Basic Miles/km', 'Corrosion Years', 'Drivetrain Miles/km',
             'Roadside Assistance Miles/km']

floatlist2 = ['Fuel Tank Capacity, Approx (gal)', 'Fuel Economy Est-Combined (MPG)', 'EPA Fuel Economy Est - City (MPG)', 'EPA Fuel Economy Est - Hwy (MPG)']

for col in floatlist1:
    try:
        #                 Remove all besides numbers and .    Save only last occurrence of .          Replace blank strings with np.nan
        df[col] = df[col].replace('[^\d.]', '', regex = True).replace('\.(?=[^.]*\.)','', regex=True).replace('', np.nan).astype(float)
        print('processed: ' + str(col))
    except Exception as e:
        print('FAILED for ' + str(col))
        print(e)
        
for col in floatlist2:
    try:
        #                 Remove all between ()               Remove all besides numbers and .
        df[col] = df[col].replace('\(.*\)', '', regex = True).replace('[^\d.]', '', regex = True).replace('', np.nan).astype(float)
        print('processed: ' + str(col))
    except Exception as e:
        print('FAILED for ' + str(col))
        print(e)
        
# Ensure that no extra columns got added somehow
print(raw.shape)
print(df.shape)
# Out:
# processed: Passenger Capacity
# processed: Passenger Doors
# processed: Base Curb Weight (lbs)
# processed: Front Hip Room (in)
# processed: Front Leg Room (in)
# processed: Second Shoulder Room (in)
# processed: Passenger Volume (ft³)
# processed: Second Head Room (in)
# processed: Front Shoulder Room (in)
# processed: Second Hip Room (in)
# processed: Front Head Room (in)
# processed: Second Leg Room (in)
# processed: Wheelbase (in)
# processed: Min Ground Clearance (in)
# processed: Track Width, Front (in)
# processed: Width, Max w/o mirrors (in)
# processed: Track Width, Rear (in)
# processed: Height, Overall (in)
# processed: Cargo Volume to Seat 1 (ft³)
# processed: Cargo Volume to Seat 2 (ft³)
# processed: Cargo Volume to Seat 3 (ft³)
# processed: First Gear Ratio (:1)
# processed: Sixth Gear Ratio (:1)
# processed: Fourth Gear Ratio (:1)
# processed: Seventh Gear Ratio (:1)
# processed: Second Gear Ratio (:1)
# processed: Reverse Ratio (:1)
# processed: Fifth Gear Ratio (:1)
# processed: Eighth Gear Ratio (:1)
# processed: Trans Type
# processed: Third Gear Ratio (:1)
# processed: Final Drive Axle Ratio (:1)
# processed: Rear Brake Rotor Diam x Thickness (in)
# processed: Front Brake Rotor Diam x Thickness (in)
# processed: Turning Diameter - Curb to Curb (ft)
# processed: Basic Miles/km
# processed: Corrosion Years
# processed: Drivetrain Miles/km
# processed: Roadside Assistance Miles/km
# processed: Fuel Tank Capacity, Approx (gal)
# processed: Fuel Economy Est-Combined (MPG)
# processed: EPA Fuel Economy Est - City (MPG)
# processed: EPA Fuel Economy Est - Hwy (MPG)
# (32316, 235)
# (32316, 241)

# %%
# parse year from model
df['model_year'] = df['model'].str.extract('(\d{4})').astype(int)
df['model_year'].value_counts(dropna=False)
# Out:
# 2018    2801
# 2019    2431
# 2016    2225
# 2015    2103
# 2013    1898
# 2014    1897
# 2012    1870
# 2011    1671
# 2010    1456
# 2009    1437
# 2008    1382
# 2007    1294
# 2006    1192
# 2005    1116
# 2004    1034
# 2003     848
# 2002     753
# 2001     732
# 2000     586
# 1999     543
# 1998     471
# 1997     469
# 1996     391
# 1995     385
# 1994     298
# 1992     286
# 1991     261
# 1993     251
# 1990     235
# Name: model_year, dtype: int64

# %%
# Parse displacement column
df['Displacement_parse'] = df['Displacement'].str.extract('(\d+\.?\d+)')
df['Displacement_parse'].replace('', np.nan, inplace = True)
df['Displacement_parse'] = df['Displacement_parse'].str.strip()
df['Displacement_parse'] = df['Displacement_parse'].astype(float)

# %%
# parse HP column for HP and RPM
df['SAE HP parse'] = df['SAE Net Horsepower @ RPM'].str.split(' ')
df['SAE HP'] = df['SAE HP parse'].str[0]
df['SAE HP RPM'] = df['SAE HP parse'].str[-1]

# drop intermediate column
df.drop(columns = ['SAE HP parse'], inplace = True)

# convert to floats
def to_number(s):
    try:
        s1 = float(s)
        return s1
    except ValueError:
        return np.nan
    
df['SAE HP'] = df['SAE HP'].apply(lambda x : to_number(x))  
df['SAE HP RPM'] = df['SAE HP RPM'].apply(lambda x : to_number(x))

# %%
 # parse Torque column for Torque and RPM
df['SAE Torque parse'] = df['SAE Net Torque @ RPM'].str.split(' ')
df['SAE Torque'] = df['SAE Torque parse'].str[0]
df['SAE Torque RPM'] = df['SAE Torque parse'].str[-1]

# drop intermediate column
df.drop(columns = ['SAE Torque parse'], inplace = True)

# convert to floats
df['SAE Torque'] = df['SAE Torque'].apply(lambda x : to_number(x))  
df['SAE Torque RPM'] = df['SAE Torque RPM'].apply(lambda x : to_number(x))

# %%
df.isnull().sum().sort_values().hist();

# %%
# investigating MPG
MPG_response = ['Fuel Tank Capacity, Approx (gal)', 'Fuel Economy Est-Combined (MPG)', 'EPA Fuel Economy Est - City (MPG)', 'EPA Fuel Economy Est - Hwy (MPG)']
df[MPG_response].isnull().sum()
# Out:
# 0
# Fuel Tank Capacity, Approx (gal)      2168
# Fuel Economy Est-Combined (MPG)      14910
# EPA Fuel Economy Est - City (MPG)     5289
# EPA Fuel Economy Est - Hwy (MPG)      5293
# dtype: int64

# %%
# Heatmap to show what percentage of values exists per year
sns.heatmap(1/df.groupby('model_year').count().rdiv(df.groupby('model_year').size(), axis=0)[MPG_response]);

# %%
# Heatmap showing how many missing predictor values there are per year
MPG_predicting = ['model', 'MSRP', 'Body Style', 'Base Curb Weight (lbs)', 'SAE Torque', 'SAE HP', 'Displacement_parse', 'EPA Class', 'Drivetrain', 'Fuel System']
sns.heatmap(1/df.groupby('model_year').count().rdiv(df.groupby('model_year').size(), axis=0)[MPG_predicting]);

# %%
MPG_features = ['model_year', 'MSRP', 'Body Style', 'SAE Torque', 'SAE HP', 'Displacement_parse', 'Drivetrain', 'Fuel System', 'EPA Fuel Economy Est - City (MPG)']
# removed: model, EPA Class, 
fullresponse_df = df.dropna(subset = ['EPA Fuel Economy Est - City (MPG)'])[MPG_features]
fullresponse_df.head()
# Out:
# 0  model_year     MSRP     Body Style  SAE Torque  SAE HP  Displacement_parse  \
# 1        2019  40600.0  Sport Utility       280.0   272.0                 2.0
# 2        2019  45500.0  Sport Utility       280.0   272.0                 2.0
# 3        2019  43600.0  Sport Utility       280.0   272.0                 2.0
# 4        2019  37400.0  Sport Utility       280.0   272.0                 2.0
# 5        2019  42600.0  Sport Utility       280.0   272.0                 2.0
#
# 0         Drivetrain                Fuel System  \
# 1  Front Wheel Drive  Gasoline Direct Injection
# 2  Front Wheel Drive  Gasoline Direct Injection
# 3  Front Wheel Drive  Gasoline Direct Injection
# 4  Front Wheel Drive  Gasoline Direct Injection
# 5    All Wheel Drive  Gasoline Direct Injection
#
# 0  EPA Fuel Economy Est - City (MPG)
# 1                               22.0
# 2                               22.0
# 3                               22.0
# 4                               22.0
# 5                               21.0

# %%
# Clean categorical Columns
drivetrain_dict = {'Front Wheel Drive' :'Front Wheel Drive',
                   'Rear Wheel Drive': 'Rear Wheel Drive',
                   'All Wheel Drive': 'All Wheel Drive',
                   '4-Wheel Drive': '4 Wheel Drive',
                   'Four Wheel Drive': '4 Wheel Drive',
                   'All-Wheel Drive': 'All Wheel Drive',
                   '4 Wheel Drive': '4 Wheel Drive',
                   'Front-Wheel Drive': 'Front Wheel Drive',
                   'Four-Wheel Drive': '4 Wheel Drive',
                   'Rear wheel drive': 'Rear Wheel Drive',
                   'Front wheel drive': 'Front Wheel Drive',
                   'AWD': 'All Wheel Drive',
                   'Rear-Wheel Drive': 'Rear Wheel Drive',
                   '4WD': '4 Wheel Drive',
                   'All wheel drive': 'All Wheel Drive',
                   '2 Wheel Drive': '2 Wheel Drive',
                   'REAR WHEEL DRIVE': 'Rear Wheel Drive',
                   'Four wheel drive': '4 Wheel Drive',
                   'All-wheel drive': 'All Wheel Drive',
                   'Front-wheel drive': 'Front Wheel Drive',
                   '2WD': '2 Wheel Drive',
                   '2-Wheel Drive': '2 Wheel Drive',
                   'RWD': 'Rear Wheel Drive',
                   '4-wheel Drive': '4 Wheel Drive'
                  }
fullresponse_df['Drivetrain'] = fullresponse_df['Drivetrain'].map(drivetrain_dict)
fullresponse_df['Drivetrain'].value_counts()
# Out:
# Front Wheel Drive    8772
# Rear Wheel Drive     7400
# All Wheel Drive      5723
# 4 Wheel Drive        5093
# 2 Wheel Drive          39
# Name: Drivetrain, dtype: int64

# %%
fullresponse_df['Fuel System'].value_counts()
# Out:
# Gasoline Direct Injection    4102
# Sequential MPI               3378
# Electronic Fuel Injection    2896
# SMPI                         2497
# Direct Injection             2299
# SFI                          2130
# EFI                          2078
# MPFI                         2018
# SEFI                         1230
# MPI                           805
# MFI                           636
# Port/Direct Injection         465
# PGM-FI                        270
# DI                            200
# FSI                           198
# Diesel Direct Injection       167
# SIDI                          148
# SMFI                           70
# Turbocharged DI                66
# TFSI                           54
# SPFI                           53
# Electronic fuel injection      52
# FFV                            51
# Direct Gasoline Injection      40
# Turbocharged SMPI              35
# TDI                            31
# SFI FlexFuel                   28
# TFSI Direct                    24
# Turbocharged EFI               23
# Turbocharged                   22
# EMPI                           21
# Direct injection               19
# GDI                            17
# SDI                            16
# PGM-FI MPI                     15
# DISI                           13
# SFI/DI                          9
# SPI                             8
# NDIS                            8
# CDI                             6
# Electronic Fuel Injectino       6
# Direct                          6
# DOHC FSI Direct                 6
# Supercharged EFI                6
# FSI Direct                      5
# DIS                             4
# PFI                             4
# Turbo-Diesel                    2
# Turbocharged FSI                2
# SI                              2
# FI                              2
# HPI                             2
# SMPFI                           1
# Sequential Fuel Injection       1
# Turbocharged EMFI               1
# Supercharged SPFI               1
# Name: Fuel System, dtype: int64

# %%
#clean NaNs - revisit this
fullresponse_df.dropna(inplace = True)
X.isnull().sum().sort_values(ascending = False)
# Out:
# Fuel System_Turbocharged SMPI                   0
# Drivetrain_Rear Wheel Drive                     0
# Body Style_Regular Cab Pickup - Short Bed       0
# Body Style_Regular Cab Pickup - Standard Bed    0
# Body Style_Sport Utility                        0
# Body Style_Station Wagon                        0
# Drivetrain_4 Wheel Drive                        0
# Drivetrain_All Wheel Drive                      0
# Drivetrain_Four Wheel Drive                     0
# Drivetrain_Front Wheel Drive                    0
# Fuel System_DI                                  0
# Body Style_Regular Cab Chassis-Cab              0
# Fuel System_DIS                                 0
# Fuel System_DISI                                0
# Fuel System_DOHC FSI Direct                     0
# Fuel System_Diesel Direct Injection             0
# Fuel System_Direct                              0
# Fuel System_Direct Gasoline Injection           0
# Fuel System_Direct Injection                    0
# Fuel System_Direct injection                    0
# Body Style_Regular Cab Pickup - Long Bed        0
# Body Style_Mini-van, Passenger                  0
# Fuel System_EMPI                                0
# Body Style_Crew Cab Pickup - Long Bed           0
# MSRP                                            0
# SAE Torque                                      0
# SAE HP                                          0
# Displacement_parse                              0
# Body Style_3dr Car                              0
# Body Style_4dr Car                              0
#                                                ..
# Fuel System_TFSI                                0
# Fuel System_TFSI Direct                         0
# Fuel System_Turbo-Diesel                        0
# Fuel System_Turbocharged                        0
# Fuel System_Turbocharged DI                     0
# Fuel System_Turbocharged EFI                    0
# Fuel System_Turbocharged EMFI                   0
# Fuel System_SI                                  0
# Fuel System_SFI FlexFuel                        0
# Fuel System_Electronic Fuel Injection           0
# Fuel System_MFI                                 0
# Fuel System_Electronic fuel injection           0
# Fuel System_FFV                                 0
# Fuel System_FI                                  0
# Fuel System_FSI                                 0
# Fuel System_FSI Direct                          0
# Fuel System_GDI                                 0
# Fuel System_Gasoline Direct Injection           0
# Fuel System_HPI                                 0
# Fuel System_MPFI                                0
# Fuel System_SFI                                 0
# Fuel System_MPI                                 0
# Fuel System_NDIS                                0
# Fuel System_PFI                                 0
# Fuel System_PGM-FI                              0
# Fuel System_PGM-FI MPI                          0
# Fuel System_Port/Direct Injection               0
# Fuel System_SDI                                 0
# Fuel System_SEFI                                0
# model_year                                      0
# Length: 87, dtype: int64

# %%
cat_list = fullresponse_df.select_dtypes(include = ['object']).columns.tolist()
dummies = pd.get_dummies(fullresponse_df[cat_list], prefix = cat_list, dummy_na = False, drop_first = True)
X = fullresponse_df.drop(columns = cat_list).join(dummies).drop(columns = ['EPA Fuel Economy Est - City (MPG)'])
y = fullresponse_df['EPA Fuel Economy Est - City (MPG)']
print(X.shape)
print(y.shape)
#fullresponse_df.columns
# Out:
# (26249, 86)
# (26249,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42)

# Instantiate
lm_model = LinearRegression(normalize=True) 

# Fit 
lm_model.fit(X_train, y_train) 

#Predict and score the model
y_train_preds = lm_model.predict(X_train)
y_test_preds = lm_model.predict(X_test)

train_score = r2_score(y_train, y_train_preds)
test_score = r2_score(y_test, y_test_preds)
print("The rsquared on the training data was {}.  The rsquared on the test data was {}.".format(train_score, test_score))
# Out:
# The rsquared on the training data was 0.6998356709810531.  The rsquared on the test data was 0.7037650213938973.

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                                   est_int     coefs  abs_coefs
# 79               Fuel System_Turbo-Diesel  8.707270   8.707270
# 81            Fuel System_Turbocharged DI  7.292171   7.292171
# 56                        Fuel System_PFI -6.689115   6.689115
# 34            Fuel System_DOHC FSI Direct -6.329188   6.329188
# 33                       Fuel System_DISI -5.989232   5.989232
# 17     Body Style_Full-size Passenger Van -5.793452   5.793452
# 77                       Fuel System_TFSI -5.485293   5.485293
# 8              Body Style_Crew Cab Pickup -5.028032   5.028032
# 19             Body Style_Mini-van, Cargo -4.984482   4.984482
# 65                         Fuel System_SI -4.970368   4.970368
# 60                        Fuel System_SDI -4.760601   4.760601
# 36                     Fuel System_Direct -4.666784   4.666784
# 49                        Fuel System_GDI -4.659622   4.659622
# 85          Fuel System_Turbocharged SMPI -4.621927   4.621927
# 66                       Fuel System_SIDI -4.615171   4.615171
# 78                Fuel System_TFSI Direct -4.611621   4.611621
# 47                        Fuel System_FSI -4.571236   4.571236
# 46                         Fuel System_FI -4.506592   4.506592
# 74           Fuel System_Supercharged EFI -4.474916   4.474916
# 42  Fuel System_Electronic Fuel Injectino -4.431670   4.431670

# %%
sns.heatmap(fullresponse_df.corr(), annot = True, fmt = '.2f')
